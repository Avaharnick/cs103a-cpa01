# %% [markdown]
# ## PA One, part A
# This data shows data about how likely certain people are to default on creedit card debt.
# URL  : https://www.kaggle.com/gauravtopre/credit-card-defaulter-prediction
# To find this data set go to kaggel.com and search credit card debt
# Question one: Do people with more education have a higher or lower pay0?
# Question how: Are people under 30 more likely default an debt than people over 30?

# %% [markdown]
# ## PART B

# %%
import pandas as pd
data = pd.read_csv('Credit Card Defaulter Prediction.csv')

# %% [markdown]
# ## PART C

# %%
description = data.describe()
description
# Out:
#                  ID       LIMIT_BAL           AGE         PAY_0         PAY_2  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667     35.485500     -0.016700     -0.133767
# std     8660.398374   129747.661567      9.217904      1.123802      1.197186
# min        1.000000    10000.000000     21.000000     -2.000000     -2.000000
# 25%     7500.750000    50000.000000     28.000000     -1.000000     -1.000000
# 50%    15000.500000   140000.000000     34.000000      0.000000      0.000000
# 75%    22500.250000   240000.000000     41.000000      0.000000      0.000000
# max    30000.000000  1000000.000000     79.000000      8.000000      8.000000
#
#               PAY_3         PAY_4         PAY_5         PAY_6      BILL_AMT1  \
# count  30000.000000  30000.000000  30000.000000  30000.000000   30000.000000
# mean      -0.166200     -0.220667     -0.266200     -0.291100   51223.330900
# ...

# %% [markdown]
# ## Part D

# %%
cols= data.columns
cols

# %%
ind = data.index.array
ind

# %%
import numpy as np
import matplotlib.pyplot as plt 
x= data['AGE'].values
y = data['LIMIT_BAL'].values
plt.ylabel('Limit balance')
plt.xlabel('Age')
plt.title('Age and Limit Balance')
plt.plot(x,y)
plt.show()

# %%
column = "LIMIT_BAL" 
pivot = pd.pivot_table(data, values=column, index=["AGE"], columns = 'EDUCATION' ).dropna()
pivot
pivot.plot()
plt.grid()

# %%
data
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000   F   University  Married   24      2      2     -1
# 1          2     120000   F   University   Single   26     -1      2      0
# 2          3      90000   F   University   Single   34      0      0      0
# 3          4      50000   F   University  Married   37      0      0      0
# 4          5      50000   M   University  Married   57     -1      0     -1
# ...      ...        ...  ..          ...      ...  ...    ...    ...    ...
# 29995  29996     220000   M  High School  Married   39      0      0      0
# 29996  29997     150000   M  High School   Single   43     -1     -1     -1
# 29997  29998      30000   M   University   Single   37      4      3      2
# 29998  29999      80000   M  High School  Married   41      1     -1      0
# 29999  30000      50000   M   University  Married   46      0      0      0
#
# ...

# %%
group = data.groupby('EDUCATION')['PAY_AMT1'].agg(sum)
group
# Out:
# EDUCATION
# 0                     83241
# Graduate school    71776182
# High School        23928076
# Others               670413
# University         71278900
# Unknown             2170603
# Name: PAY_AMT1, dtype: int64

# %% [markdown]
# ## PART E, Discussion cell
# This data tells us that on average, younger people have a lower balance than older people.
# This also shows that age and education does not have a strong correlation with limit balance.
# However, people in their late 30's whoses education is "other" have a higher limit blance.
# Those with more education have a higher payer amount one.
